# %%
import Functions as F
import importlib
import time

# %% [markdown]
# ## Ex 0.2

# %%
importlib.reload(F)
N = 100
M = 5
T = 15
start_time = time.time()
state, patterns = F.run_standard_hopfield_network(N,M,T)
print("Computational cost:", time.time() - start_time, "seconds")
F.plot_standard_hopfield_network_results(M,state,patterns)

##Check overlaps of final state with every patterns ##############
overlaps=F.compute_overlap(state,patterns)
i=1
for overlap in overlaps: 
    print(f"overlap pattern {i}: {overlap}")
    i+=1
# Out:
# Computational cost: 0.007969379425048828 seconds
# overlap pattern 1: 0.9988362079507048
# overlap pattern 2: -0.12074103791831554
# overlap pattern 3: 0.020040677612478155
# overlap pattern 4: 0.120678312183903
# overlap pattern 5: 0.04014319731998678
