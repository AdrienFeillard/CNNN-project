# %%
import Functions as F
import importlib
import time
import random

# %% [markdown]
# ## Ex 0.2

# %%
importlib.reload(F)

N = 100
M = 5
T = 15
start_time = time.time()
state, patterns = F.run_standard_hopfield_network(N,M,T)
print("Computational cost:", time.time() - start_time, "seconds")
F.plot_standard_hopfield_network_results(M,state,patterns)

##Check overlaps of final state with every patterns ##############
overlaps=F.compute_overlap(state,patterns)
i=1
for overlap in overlaps: 
    print(f"overlap pattern {i}: {overlap}")
    i+=1
# Out:
# Computational cost: 0.0015940666198730469 seconds
# overlap pattern 1: 0.9987381836199509
# overlap pattern 2: -0.020064589286207236
# overlap pattern 3: 0.06048306320232772
# overlap pattern 4: -0.16101467112275686
# overlap pattern 5: -0.04022727713777833
